# %%
import numpy as np
import matplotlib.pyplot as plt
from enum import Enum
from queue import PriorityQueue
from scipy.spatial import Voronoi
from bresenham import bresenham

# %%
def create_grid(data, drone_altitude, safety_distance):
    """
    Returns a grid representation of a 2D configuration space
    based on given obstacle data, drone altitude and safety distance
    arguments.
    """

    # minimum and maximum north coordinates
    north_min = np.floor(np.min(data[:, 0] - data[:, 3]))
    north_max = np.ceil(np.max(data[:, 0] + data[:, 3]))
    print(north_min, north_max)

    # minimum and maximum east coordinates
    east_min = np.floor(np.min(data[:, 1] - data[:, 4]))
    east_max = np.ceil(np.max(data[:, 1] + data[:, 4]))
    print(east_min, east_max)
    # given the minimum and maximum coordinates we can
    # calculate the size of the grid.
    north_size = int(np.ceil((north_max - north_min)))
    east_size = int(np.ceil((east_max - east_min)))
    print(north_size, east_size)
    # Initialize an empty grid
    grid = np.zeros((north_size, east_size))
    # Center offset for grid
    north_min_center = np.min(data[:, 0])
    east_min_center = np.min(data[:, 1])
    # Populate the grid with obstacles
    for i in range(data.shape[0]):
        north, east, alt, d_north, d_east, d_alt = data[i, :]

        if alt + d_alt + safety_distance > drone_altitude:
            obstacle = [
                int(north - d_north - safety_distance - north_min_center),
                int(north + d_north + safety_distance - north_min_center),
                int(east - d_east - safety_distance - east_min_center),
                int(east + d_east + safety_distance - east_min_center),
            ]
            grid[obstacle[0]:obstacle[1], obstacle[2]:obstacle[3]] = 1

    return grid



def a_star(grid, heuristic_func, start, goal):
    """
    Given a grid and heuristic function returns
    the lowest cost path from start to goal.
    """

    path = []
    path_cost = 0
    queue = PriorityQueue()
    queue.put((0, start))
    visited = set(start)

    branch = {}
    found = False

    while not queue.empty():
        item = queue.get()
        current_cost = item[0]
        current_node = item[1]

        if current_node == goal:
            print('Found a path.')
            found = True
            break
        else:
            # Get the new vertexes connected to the current vertex
            for a in valid_actions(grid, current_node):
                next_node = (current_node[0] + a.delta[0], current_node[1] + a.delta[1])
                new_cost = current_cost + a.cost + heuristic_func(next_node, goal)

                if next_node not in visited:
                    visited.add(next_node)
                    queue.put((new_cost, next_node))

                    branch[next_node] = (new_cost, current_node, a)

    if found:
        # retrace steps
        n = goal
        path_cost = branch[n][0]
        while branch[n][1] != start:
            path.append(branch[n][1])
            n = branch[n][1]
        path.append(branch[n][1])

    return path[::-1], path_cost


# Assume all actions cost the same.
class Action(Enum):
    """
    An action is represented by a 3 element tuple.

    The first 2 values are the delta of the action relative
    to the current grid position. The third and final value
    is the cost of performing the action.
    """
    NORTHWEST = (-1, -1, np.sqrt(2))
    SOUTHWEST = (1, -1, np.sqrt(2))
    NORTHEAST = (-1, 1, np.sqrt(2))
    SOUTHEAST = (1, 1, np.sqrt(2))
    WEST = (0, -1, 1)
    EAST = (0, 1, 1)
    NORTH = (-1, 0, 1)
    SOUTH = (1, 0, 1)

    @property
    def cost(self):
        return self.value[2]

    @property
    def delta(self):
        return (self.value[0], self.value[1])


def valid_actions(grid, current_node):
    """
    Returns a list of valid actions given a grid and current node.
    """
    valid_actions = list(Action)
    n, m = grid.shape[0] - 1, grid.shape[1] - 1
    x, y = current_node

    #print("X: {} Y: {}".format(x,y))
    if x - 1 < 0 or grid[x - 1, y] == 1:
        valid_actions.remove(Action.NORTH)
        #print("Removed NORTH")
    if x + 1 > n or grid[x + 1, y] == 1:
        valid_actions.remove(Action.SOUTH)
        #print("Removed SOUTH")
    if y - 1 < 0 or grid[x, y - 1] == 1:
        valid_actions.remove(Action.WEST)
        #print("Removed WEST")
    if y + 1 > m or grid[x, y + 1] == 1:
        valid_actions.remove(Action.EAST)
        #print("Removed EAST")
    if x - 1 < 0 and y + 1 > m or grid[x - 1, y + 1] == 1:
        valid_actions.remove(Action.NORTHEAST)
        #print("Removed NORTHEAST")
    if x - 1 < 0 and y - 1 < 0 or grid[x - 1,y - 1] == 1:
        valid_actions.remove(Action.NORTHWEST)
        #print("Removed NORTHWEST")
    if x + 1 > n and y + 1 > m or grid[x + 1,y + 1] == 1:
        valid_actions.remove(Action.SOUTHEAST)
        #print("Removed SOUTHEAST")
    if x + 1 > n and y -1 < 0 or grid[x + 1,y - 1] == 1:
        valid_actions.remove(Action.SOUTHWEST)
        #print("Removed SOUTHWEST")
        
    return valid_actions

# %%
data = np.loadtxt('colliders.csv', delimiter=',', dtype='Float64', skiprows=2)

# %%
TARGET_ALTITUDE = 5
SAFETY_DISTANCE = 3

# %%
grid = create_grid(data, TARGET_ALTITUDE, SAFETY_DISTANCE)
# Out:
# -316.0 605.0
# -445.0 476.0
# 921 921

# %%
def heuristic_func(position, goal_position):
    return np.abs(position[0] - goal_position[0]) + np.abs(position[1] - goal_position[1])

def point(p):
    return np.array([p[0], p[1], 1.]).reshape(1, -1)

def collinearity_check(p1, p2, p3, epsilon=1e-6):   
    m = np.concatenate((p1, p2, p3), 0)
    det = np.linalg.det(m)
    return abs(det) < epsilon

def prune_path(path):
    pruned_path = [p for p in path]
    # TODO: prune the path!
    
    i = 0
    while i < len(pruned_path) - 2:
        p1 = point(pruned_path[i])
        p2 = point(pruned_path[i+1])
        p3 = point(pruned_path[i+2])
        
        # If the 3 points are in a line remove
        # the 2nd point.
        # The 3rd point now becomes and 2nd point
        # and the check is redone with a new third point
        # on the next iteration.
        if collinearity_check(p1, p2, p3):
            # Something subtle here but we can mutate
            # `pruned_path` freely because the length
            # of the list is check on every iteration.
            pruned_path.remove(pruned_path[i+1])
        else:
            i += 1
    return pruned_path

# %%
#(316, 444) (739, 357)
grid_start = (316, 444)
grid_goal = (739, 357)

print('Local Start and Goal: ', grid_start, grid_goal)
path, _ = a_star(grid, heuristic_func, grid_start, grid_goal)
path = prune_path(path)

plt.plot(grid_start[1], grid_start[0], 'x')
plt.plot(grid_goal[1], grid_goal[0], 'x')

pp = np.array(path)
plt.plot(pp[:, 1], pp[:, 0], 'g')

plt.rcParams['figure.figsize'] = 12, 12
# equivalent to
# plt.imshow(np.flip(grid, 0))
plt.imshow(grid, origin='lower') 

plt.xlabel('EAST')
plt.ylabel('NORTH')
plt.show()
# Out:
# Local Start and Goal:  (316, 444) (739, 357)
# Found a path.

# %%
from skimage.morphology import medial_axis
from skimage.util import invert

# Assuming you've already created the grid
# The medial_axis() method requires that we invert the grid image
skeleton = medial_axis(invert(grid))
plt.imshow(grid, origin='lower')
plt.imshow(skeleton, origin='lower', alpha=0.7)
plt.show()

# %%
def find_start_goal(skel, start, goal):
    # TODO: find start and goal on skeleton
    # Some useful functions might be:
        # np.nonzero()
        # np.transpose()
        # np.linalg.norm()
        # np.argmin()
    skel_cells = np.transpose(skel.nonzero())
    start_min_dist = np.linalg.norm(np.array(start) - np.array(skel_cells), axis=1).argmin()
    near_start = skel_cells[start_min_dist]
    goal_min_dist = np.linalg.norm(np.array(goal) - np.array(skel_cells), axis=1).argmin()
    near_goal = skel_cells[goal_min_dist]
    
    return near_start, near_goal

skel_start, skel_goal = find_start_goal(skeleton, grid_start, grid_goal)

print(grid_start, grid_goal)
print(skel_start, skel_goal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4c5c73e6c206> in <module>()
#      14     return near_start, near_goal
#      15
# ---> 16 skel_start, skel_goal = find_start_goal(skeleton, grid_start, grid_goal)
#      17
#      18 print(grid_start, grid_goal)
#
# NameError: name 'skeleton' is not defined

# %%
path, cost = a_star(invert(skeleton).astype(np.int), heuristic_func, tuple(skel_start), tuple(skel_goal))
print("Path length = {0}, path cost = {1}".format(len(path), cost))
# Out:
# X: 316 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 317 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 315 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 318 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 316 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 314 Y: 445
# Removed NORTH
# Removed WEST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 314 Y: 446
# Removed NORTH
# Removed SOUTH
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 319 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 313 Y: 444
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 315 Y: 447
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 313 Y: 447
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 320 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 314 Y: 443
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 312 Y: 443
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 314 Y: 448
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 312 Y: 448
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 321 Y: 445
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 313 Y: 442
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 311 Y: 442
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 313 Y: 449
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 311 Y: 449
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 322 Y: 445
# Removed SOUTH
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 322 Y: 446
# Removed NORTH
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 312 Y: 441
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 310 Y: 441
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 312 Y: 450
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 310 Y: 450
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 323 Y: 444
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 322 Y: 444
# Removed NORTH
# Removed SOUTH
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 323 Y: 446
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 311 Y: 440
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 309 Y: 440
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 311 Y: 451
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 309 Y: 451
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 322 Y: 443
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 324 Y: 446
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 310 Y: 439
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 308 Y: 439
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 310 Y: 452
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 308 Y: 452
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 322 Y: 442
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 325 Y: 445
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 309 Y: 438
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 307 Y: 438
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 309 Y: 453
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 307 Y: 453
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 323 Y: 443
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 308 Y: 437
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 306 Y: 438
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 308 Y: 454
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 306 Y: 454
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 305 Y: 437
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 307 Y: 455
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 305 Y: 455
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 306 Y: 436
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 304 Y: 436
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 306 Y: 456
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 304 Y: 456
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 305 Y: 435
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 303 Y: 436
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 305 Y: 457
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 303 Y: 457
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 302 Y: 435
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 304 Y: 458
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 302 Y: 458
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 303 Y: 434
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 301 Y: 434
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 303 Y: 459
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 301 Y: 459
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 302 Y: 433
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 300 Y: 434
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 302 Y: 460
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 300 Y: 460
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 299 Y: 433
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 301 Y: 461
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 299 Y: 461
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 300 Y: 432
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 298 Y: 433
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 300 Y: 462
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 298 Y: 462
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 297 Y: 432
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 299 Y: 463
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 297 Y: 463
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 298 Y: 431
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 296 Y: 432
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 298 Y: 464
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 296 Y: 464
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 295 Y: 432
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 297 Y: 465
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 295 Y: 465
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 294 Y: 431
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 296 Y: 466
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 294 Y: 465
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 295 Y: 430
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 293 Y: 431
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 293 Y: 466
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 292 Y: 431
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 294 Y: 467
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 292 Y: 467
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 291 Y: 430
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 293 Y: 468
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 291 Y: 468
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 292 Y: 429
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 290 Y: 430
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 289 Y: 429
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 289 Y: 431
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 292 Y: 469
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 290 Y: 469
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 290 Y: 428
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 288 Y: 428
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 290 Y: 432
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 288 Y: 432
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 291 Y: 470
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 289 Y: 469
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 289 Y: 427
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 287 Y: 427
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 289 Y: 433
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 287 Y: 433
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 288 Y: 469
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 288 Y: 426
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 286 Y: 426
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 288 Y: 434
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 286 Y: 434
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 287 Y: 470
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 287 Y: 425
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 285 Y: 425
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 287 Y: 435
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 285 Y: 435
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 288 Y: 471
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 286 Y: 470
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 286 Y: 424
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 284 Y: 424
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 286 Y: 436
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 284 Y: 436
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 285 Y: 470
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 285 Y: 423
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 283 Y: 423
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 285 Y: 437
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 283 Y: 437
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 284 Y: 470
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 284 Y: 422
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 282 Y: 422
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 284 Y: 438
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 282 Y: 438
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 283 Y: 470
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 283 Y: 421
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 281 Y: 421
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 283 Y: 439
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 281 Y: 439
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 282 Y: 470
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 282 Y: 420
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 280 Y: 420
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# X: 282 Y: 440
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 280 Y: 440
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 281 Y: 471
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHWEST
# X: 281 Y: 419
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 279 Y: 419
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 279 Y: 421
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 281 Y: 441
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 279 Y: 441
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 280 Y: 470
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 282 Y: 472
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 280 Y: 472
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 280 Y: 418
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 278 Y: 418
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 280 Y: 422
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHWEST
# X: 278 Y: 422
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 280 Y: 442
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 278 Y: 442
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 281 Y: 417
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 279 Y: 417
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 277 Y: 417
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 281 Y: 469
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 279 Y: 469
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 281 Y: 423
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 279 Y: 423
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 281 Y: 473
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 280 Y: 473
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 277 Y: 423
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 279 Y: 443
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 277 Y: 443
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 282 Y: 416
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 278 Y: 416
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 276 Y: 416
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 282 Y: 424
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 278 Y: 424
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 276 Y: 424
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 282 Y: 468
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 280 Y: 468
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 278 Y: 468
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 280 Y: 474
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 278 Y: 444
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 276 Y: 444
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 283 Y: 415
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 277 Y: 415
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 275 Y: 415
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 283 Y: 425
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 277 Y: 425
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 275 Y: 425
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 279 Y: 467
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 277 Y: 467
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 280 Y: 475
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 277 Y: 445
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 284 Y: 414
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 276 Y: 414
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 274 Y: 414
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 284 Y: 426
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 276 Y: 426
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 274 Y: 426
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 278 Y: 466
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 276 Y: 466
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 280 Y: 476
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 285 Y: 413
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 275 Y: 413
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 273 Y: 413
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 285 Y: 427
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 275 Y: 427
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 273 Y: 427
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 277 Y: 465
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 280 Y: 477
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 286 Y: 412
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 274 Y: 412
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 272 Y: 412
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 286 Y: 428
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 274 Y: 428
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 272 Y: 428
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 280 Y: 478
# Removed NORTH
# Removed SOUTH
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 287 Y: 411
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 273 Y: 411
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 271 Y: 411
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 287 Y: 429
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 273 Y: 429
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 271 Y: 429
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 279 Y: 479
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# X: 288 Y: 410
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 272 Y: 410
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 270 Y: 410
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# X: 288 Y: 430
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# X: 272 Y: 430
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 270 Y: 430
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 280 Y: 480
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 278 Y: 480
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 289 Y: 409
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 271 Y: 409
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 269 Y: 409
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 269 Y: 411
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 271 Y: 431
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 269 Y: 431
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 290 Y: 408
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 281 Y: 479
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 279 Y: 481
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHWEST
# X: 277 Y: 480
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 270 Y: 408
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 268 Y: 408
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 270 Y: 412
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHWEST
# X: 268 Y: 412
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 270 Y: 432
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 268 Y: 432
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 291 Y: 407
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 271 Y: 407
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 269 Y: 407
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 267 Y: 407
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 271 Y: 413
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 269 Y: 413
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 280 Y: 482
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 267 Y: 413
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 276 Y: 480
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 269 Y: 433
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 267 Y: 433
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 292 Y: 406
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 272 Y: 406
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 268 Y: 406
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 266 Y: 406
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 272 Y: 414
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 268 Y: 414
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 266 Y: 414
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 281 Y: 483
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 275 Y: 480
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 268 Y: 434
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 266 Y: 434
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 293 Y: 405
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 273 Y: 405
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 267 Y: 405
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 265 Y: 405
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 273 Y: 415
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 267 Y: 415
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 265 Y: 415
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 282 Y: 484
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 274 Y: 480
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 267 Y: 435
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 294 Y: 404
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 274 Y: 404
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 266 Y: 404
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 264 Y: 404
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 274 Y: 416
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 266 Y: 416
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 264 Y: 416
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 283 Y: 485
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 273 Y: 480
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 275 Y: 403
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 265 Y: 403
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 263 Y: 403
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 275 Y: 417
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 265 Y: 417
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 263 Y: 417
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 284 Y: 486
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 272 Y: 481
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 276 Y: 402
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 264 Y: 402
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 262 Y: 402
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 276 Y: 418
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 264 Y: 418
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 262 Y: 418
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 273 Y: 482
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 271 Y: 481
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 277 Y: 401
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 263 Y: 401
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 261 Y: 401
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 277 Y: 419
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 263 Y: 419
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 261 Y: 419
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 270 Y: 480
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 270 Y: 482
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 278 Y: 400
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 262 Y: 400
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 260 Y: 400
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# X: 278 Y: 420
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# X: 262 Y: 420
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 260 Y: 420
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 279 Y: 399
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 271 Y: 479
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 269 Y: 479
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 271 Y: 483
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 270 Y: 483
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 261 Y: 399
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 259 Y: 399
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 259 Y: 401
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 261 Y: 421
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 259 Y: 421
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 280 Y: 398
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 260 Y: 398
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 258 Y: 398
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 260 Y: 402
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHWEST
# X: 258 Y: 402
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 270 Y: 478
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 268 Y: 478
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 270 Y: 484
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 260 Y: 422
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 258 Y: 422
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 281 Y: 397
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 261 Y: 397
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 259 Y: 397
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 257 Y: 397
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 261 Y: 403
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 259 Y: 403
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 257 Y: 403
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 269 Y: 477
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 267 Y: 477
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 270 Y: 485
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 259 Y: 423
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 257 Y: 423
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 282 Y: 396
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 262 Y: 396
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 258 Y: 396
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 256 Y: 396
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 262 Y: 404
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 258 Y: 404
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 256 Y: 404
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 268 Y: 476
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 266 Y: 476
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 270 Y: 486
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 258 Y: 424
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 256 Y: 424
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 283 Y: 395
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 263 Y: 395
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 257 Y: 395
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 255 Y: 395
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 263 Y: 405
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 257 Y: 405
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 255 Y: 405
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 257 Y: 425
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 267 Y: 475
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 270 Y: 487
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 284 Y: 394
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 264 Y: 394
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 256 Y: 394
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 254 Y: 394
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 264 Y: 406
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 256 Y: 406
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 254 Y: 406
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 270 Y: 488
# Removed NORTH
# Removed SOUTH
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 265 Y: 393
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 255 Y: 393
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 253 Y: 393
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 265 Y: 407
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 255 Y: 407
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 253 Y: 407
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 269 Y: 489
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# X: 266 Y: 392
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 254 Y: 392
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 252 Y: 392
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 266 Y: 408
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 254 Y: 408
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 252 Y: 408
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 267 Y: 391
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 270 Y: 490
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 268 Y: 489
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 253 Y: 391
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 251 Y: 391
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# X: 267 Y: 409
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 253 Y: 409
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 251 Y: 409
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 268 Y: 390
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 252 Y: 390
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 250 Y: 390
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# X: 268 Y: 410
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# X: 271 Y: 489
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 267 Y: 490
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 252 Y: 410
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 250 Y: 410
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 269 Y: 389
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 251 Y: 389
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 249 Y: 390
# Removed NORTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 251 Y: 411
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 249 Y: 411
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHWEST
# X: 268 Y: 491
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# ...
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 845
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 845
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 6 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 846
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 846
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 7 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 847
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 847
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 8 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 848
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 848
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 9 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 849
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 849
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 10 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 850
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 850
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 11 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 851
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 851
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 12 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 852
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 852
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 13 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 853
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 853
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 14 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 854
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 854
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 15 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 855
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 855
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 16 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 856
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 856
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 17 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 857
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 857
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 18 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 858
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 858
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 19 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 859
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 859
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 20 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 860
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 860
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 21 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 861
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 861
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 22 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 862
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 862
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 23 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 863
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 863
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 24 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 864
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 864
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 25 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 865
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 865
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 26 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 866
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 866
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 27 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 867
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 867
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 28 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 868
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 868
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 29 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 869
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 869
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 30 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 870
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 870
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 31 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 871
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 871
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 32 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 872
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 872
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 33 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 873
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 873
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 34 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 35 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 874
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 874
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 36 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 875
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 875
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 37 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 876
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 876
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 38 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 877
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 877
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 39 Y: 840
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 878
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 878
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 40 Y: 840
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 0 Y: 879
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 879
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 41 Y: 839
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHWEST
# Removed SOUTHEAST
# X: 0 Y: 880
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 880
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 42 Y: 838
# Removed NORTH
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed NORTHEAST
# Removed NORTHWEST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 881
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 881
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 882
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 882
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 883
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 883
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 884
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 884
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 885
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 885
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 886
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 886
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 887
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 887
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 888
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 888
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 889
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 889
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 890
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 890
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 891
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 891
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 892
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 892
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 893
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 893
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 894
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 894
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 895
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 895
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 896
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 896
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 897
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 897
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 898
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 898
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 899
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 899
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 900
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 900
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 901
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 901
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 902
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 902
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 903
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 903
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 904
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 904
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 905
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 905
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 906
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 906
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 907
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 907
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 908
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 908
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 909
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 909
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 910
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 910
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 911
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 911
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 912
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 912
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 913
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 913
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 914
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 914
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 915
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 915
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 916
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 916
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 917
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 917
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 918
# Removed NORTH
# Removed SOUTH
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: -1 Y: 918
# Removed NORTH
# Removed NORTHEAST
# Removed NORTHWEST
# X: 0 Y: 919
# Removed NORTH
# Removed SOUTH
# Removed NORTHEAST
# Removed SOUTHEAST
# X: -1 Y: 919
# Removed NORTH
# Removed EAST
# Removed NORTHWEST
# X: 1 Y: 918
# Removed SOUTH
# Removed WEST
# Removed EAST
# Removed SOUTHEAST
# Removed SOUTHWEST
# X: 0 Y: 920
# Removed NORTH
# Removed EAST
# Removed NORTHEAST
# Removed SOUTHEAST
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-aba1ebe94c6b> in <module>()
# ----> 1 path, cost = a_star(invert(skeleton).astype(np.int), heuristic_func, tuple(skel_start), tuple(skel_goal))
#       2 print("Path length = {0}, path cost = {1}".format(len(path), cost))
#
# <ipython-input-55-7900fd871478> in a_star(grid, heuristic_func, start, goal)
#      67         else:
#      68             # Get the new vertexes connected to the current vertex
# ---> 69             for a in valid_actions(grid, current_node):
#      70                 next_node = (current_node[0] + a.delta[0], current_node[1] + a.delta[1])
#      71                 new_cost = current_cost + a.cost + heuristic_func(next_node, goal)
#
# <ipython-input-55-7900fd871478> in valid_actions(grid, current_node)
#     177         valid_actions.remove(Action.SOUTHEAST)
#     178         print("Removed SOUTHEAST")
# --> 179     if x + 1 > n and y + 1 > m or grid[x + 1,y + 1] == 1:
#     180         valid_actions.remove(Action.SOUTHWEST)
#     181         print("Removed SOUTHWEST")
#
# IndexError: index 921 is out of bounds for axis 1 with size 921
